# %%
from Cours import PriceSeries
from Cours import Asset

# %%
def max_list(list: list) -> float:
    max=list[0]
    for i in list:
        if i>max:
            max=i
    return max
print(max_list([3, 7, 2, 19, 4]))
# → 19
# Out:
# 19

# %%
dict_test = {("2025","2026"): ([100,102],("2025","2026")), "clé2": "valeur2"}
print(dict_test[("2025","2026")][0])
# Out:
# [100, 102]

# %%
list_asset=[("AAPL", 100), ("MSFT", 102), ("GOOGL", 103)]

# %%
tickers = ['APPL', 'MSFT', 'GOOGL']
prices = [150, 280, 140]

# %%
price_dict = {ticker: prix for ticker, prix in zip(tickers, prices)}

# %%
price_dict
# Out:
# {'APPL': 150, 'MSFT': 280, 'GOOGL': 140}

# %%
ps = PriceSeries([100, 102, 105, 110], "Close")
print(ps.get_all_log_returns())
# Out:
# [0.01980262729617973, 0.028987536873252187, 0.04652001563489291]

# %%
from Cours import PriceSeries
from Cours import Asset
ps1 = PriceSeries([100, 102, 105, 110, 56416], "Close")
ps2 = PriceSeries([100, 102, 105, 110, 419849], "Close")
asset1 = Asset("test1", ps1, "tech")
asset2 = Asset("test2", ps2, "tech")

# %%
asset1.correlation_with(asset2)
# Out:
# 0.9999996195266421

# %%
asset1.correlation_with_synthaxe(asset2)
# Out:
# 0.9999996195266421
